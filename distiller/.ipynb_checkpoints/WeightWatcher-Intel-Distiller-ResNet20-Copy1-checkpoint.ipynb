# %% [markdown]
# # ResNet20 Models
#
# ### Found in
#
# <pre>
# distiller/examples/ssl/checkpoints/
# </pre>
#
#
# See also: https://nervanasystems.github.io/distiller/model_zoo.html#distiller-model-zoo
#
# We examine 3 sets of pretrained models
#
#     - 4D_regularized_5Lremoved.pth.tar
#     - 4D_regularized_5Lremoved_finetuned.pth.tar
#
#     - channel_regularized_resnet20.pth.tar
#     - channel_regularized_resnet20_finetuned.pth.tar
#
#     - dense.pth.tar'
#     - ch_regularized_dense.pth.tar'
#
# For the 4D_regularized models, Distiller has the unusual effect of increasing the norms
# of the W feature maps from at least 2 of the Conv2D layers
#
# We suspect this effect arises because Distiller is concentraining Frobenius mass
# from the 5 removed Conv2D layers into these remaining layers
#
# For the other pretrained models, the channel_regularized models have nearly the same accuracy, with some slight changes in the norm metrics.  The dense models , however, also display unusual behavior.

# %%
# Suppress the powerlaw package warnings
# "powerlaw.py:700: RuntimeWarning: divide by zero encountered in true_divide"
# "powerlaw.py:700: RuntimeWarning: invalid value encountered in true_divide"
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %%
# Load some common jupyter code
# %run './distiller_jupyter_helpers.ipynb'
from distiller.models import create_model
from distiller.apputils import *
import qgrid

from ipywidgets import *
from bqplot import *
import bqplot.pyplot as bqplt
from functools import partial

import weightwatcher as ww

import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

logger.setLevel(logging.INFO)

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

marker_size = 75
plt.rcParams['figure.figsize'] = [5,5]
matplotlib.rcParams.update({'font.size': 20})
legend_prop={'size':16}
# Out:
# /Users/charleshmartin/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
ww.__version__
# Out:
# '0.1.2'

# %% [markdown]
# ## Resnet20

# %%
# !ls /Users/charleshmartin/work/distiller/examples/ssl/checkpoints/
# Out:
# checkpoint_trained_4D_regularized_5Lremoved.pth.tar
# checkpoint_trained_4D_regularized_5Lremoved_finetuned.pth.tar
# checkpoint_trained_ch_regularized_dense.pth.tar
# checkpoint_trained_channel_regularized_resnet20.pth.tar
# checkpoint_trained_channel_regularized_resnet20_finetuned.pth.tar
# checkpoint_trained_dense.pth.tar

# %%
cpfiles = {
    'checkpoint_trained_4D_regularized_5Lremoved.pth.tar': 90.620,
    'checkpoint_trained_4D_regularized_5Lremoved_finetuned.pth.tar': 94.240,
    'checkpoint_trained_channel_regularized_resnet20.pth.tar': 91.420,
    'checkpoint_trained_channel_regularized_resnet20_finetuned.pth.tar': 91.420,
    'checkpoint_trained_dense.pth.tar': 92.540,
    'checkpoint_trained_ch_regularized_dense.pth.tar': 91.700,
}

# %% [raw]
# # can run just to check accuracies above
#
# results = {}
#
# for file, accuracy in cpfiles.items():
#     logger.info(file)
#     checkpoint_file = "/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/"+file
#
#     try:
#         resnet20_model = create_model(False, 'cifar10', 'resnet20_cifar', parallel=True)
#         load_checkpoint(resnet20_model, checkpoint_file);
#
#     except Exception as e:
#         print("Did you forget to download the checkpoint file?")
#         raise e

# %%
results = {}

result_dfs = {}
for file, accuracy in cpfiles.items():
    logger.info(file)
    checkpoint_file = "/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/"+file
    try:
        resnet20_model = create_model(False, 'cifar10', 'resnet20_cifar', parallel=True)
        load_checkpoint(resnet20_model, checkpoint_file);
        watcher = ww.WeightWatcher(model=resnet20_model, logger=logger)
        watcher.analyze(compute_alphas=True, compute_softranks=True, compute_spectralnorms=True)
        summary = watcher.get_summary()
        summary['accuracy'] = accuracy
        results[file] = summary
        
        result_dfs[file] = watcher.print_results()
    except Exception as e:
        print("Did you forget to download the checkpoint file?")
        raise e
# Out:
# INFO:__main__:checkpoint_trained_4D_regularized_5Lremoved.pth.tar
# INFO:root:=> creating resnet20_cifar model for CIFAR10
# INFO:root:=> loading checkpoint /Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_4D_regularized_5Lremoved.pth.tar
# INFO:root:=> Checkpoint contents:
# ╒═══════════════════╤═════════════╤════════════════╕
# │ Key               │ Type        │ Value          │
# ╞═══════════════════╪═════════════╪════════════════╡
# │ arch              │ str         │ resnet20_cifar │
# ├───────────────────┼─────────────┼────────────────┤
# │ best_top1         │ float       │ 90.62          │
# ├───────────────────┼─────────────┼────────────────┤
# │ compression_sched │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ epoch             │ int         │ 179            │
# ├───────────────────┼─────────────┼────────────────┤
# │ optimizer         │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ state_dict        │ OrderedDict │                │
# ╘═══════════════════╧═════════════╧════════════════╛
#
# INFO:root:Loaded compression schedule from checkpoint (epoch 179)
# WARNING:root:Optimizer could not be loaded from checkpoint.
# INFO:root:=> loaded checkpoint '/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_4D_regularized_5Lremoved.pth.tar' (epoch 179)
# INFO:__main__:
# WeightWatcher v0.1.2 by Calculation Consulting
# Analyze weight matrices of Deep Neural Networks
# https://calculationconsulting.com/
# python      version 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.15.3
# tensforflow version 1.10.1
# keras       version 2.2.2
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 0.7295551300048828, max: 7.41560173034668, avg: 4.315795421600342
# INFO:__main__:Norm compound: min: 0.8330910801887512, max: 6.924064636230469, avg: 4.315794944763184
# INFO:__main__:LogNorm: min: -0.13694187998771667, max: 0.8701463937759399, avg: 0.5175516605377197
# INFO:__main__:LogNorm compound: min: -0.08011464774608612, max: 0.8399592638015747, avg: 0.517551600933075
# INFO:__main__:Alpha: min: 1.490533392059119, max: 10.44447500619053, avg: 3.196053477405699
# INFO:__main__:Alpha compound: min: 1.5256002825714163, max: 4.1041530584371255, avg: 3.196053477405699
# INFO:__main__:Alpha Weighted: min: -4.778228304138091, max: 4.84831647823597, avg: 0.3071941264704492
# INFO:__main__:Alpha Weighted compound: min: -2.236248250745935, max: 1.842976302987391, avg: 0.30719412647044925
# INFO:__main__:Spectral Norm: min: 0.0, max: 44.74546432495117, avg: 2.17667293548584
# INFO:__main__:Spectral Norm compound: min: 0.0, max: 44.74546432495117, avg: 4.25676155090332
# INFO:__main__:Softrank: min: 1.483760952949524, max: 10.382201194763184, avg: 4.564530372619629
# INFO:__main__:Softrank compound: min: 1.7346382141113281, max: 9.40234375, avg: 4.564529895782471
# INFO:__main__:Softrank Log: min: 0.1713639348745346, max: 1.016289472579956, avg: 0.5427221059799194
# INFO:__main__:Softrank Log compound: min: 0.23802450299263, max: 0.97263503074646, avg: 0.5427221059799194
# INFO:__main__:Softrank Log Ratio: min: -0.49602872133255005, max: 1.9061362743377686, avg: 0.8794073462486267
# INFO:__main__:Softrank Log Ratio compound: min: -0.4642683267593384, max: 1.7702442407608032, avg: 0.8794072270393372
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 0.7295551300048828, max: 7.41560173034668, avg: 4.315795421600342
# INFO:__main__:Norm compound: min: 0.8330910801887512, max: 6.924064636230469, avg: 4.315794944763184
# INFO:__main__:LogNorm: min: -0.13694187998771667, max: 0.8701463937759399, avg: 0.5175516605377197
# INFO:__main__:LogNorm compound: min: -0.08011464774608612, max: 0.8399592638015747, avg: 0.517551600933075
# INFO:__main__:Alpha: min: 1.490533392059119, max: 10.44447500619053, avg: 3.196053477405699
# INFO:__main__:Alpha compound: min: 1.5256002825714163, max: 4.1041530584371255, avg: 3.196053477405699
# INFO:__main__:Alpha Weighted: min: -4.778228304138091, max: 4.84831647823597, avg: 0.3071941264704492
# INFO:__main__:Alpha Weighted compound: min: -2.236248250745935, max: 1.842976302987391, avg: 0.30719412647044925
# INFO:__main__:Spectral Norm: min: 0.0, max: 44.74546432495117, avg: 2.17667293548584
# INFO:__main__:Spectral Norm compound: min: 0.0, max: 44.74546432495117, avg: 4.25676155090332
# INFO:__main__:Softrank: min: 1.483760952949524, max: 10.382201194763184, avg: 4.564530372619629
# INFO:__main__:Softrank compound: min: 1.7346382141113281, max: 9.40234375, avg: 4.564529895782471
# INFO:__main__:Softrank Log: min: 0.1713639348745346, max: 1.016289472579956, avg: 0.5427221059799194
# INFO:__main__:Softrank Log compound: min: 0.23802450299263, max: 0.97263503074646, avg: 0.5427221059799194
# INFO:__main__:Softrank Log Ratio: min: -0.49602872133255005, max: 1.9061362743377686, avg: 0.8794073462486267
# INFO:__main__:Softrank Log Ratio compound: min: -0.4642683267593384, max: 1.7702442407608032, avg: 0.8794072270393372
# INFO:__main__:checkpoint_trained_4D_regularized_5Lremoved_finetuned.pth.tar
# INFO:root:=> creating resnet20_cifar model for CIFAR10
# INFO:root:=> loading checkpoint /Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_4D_regularized_5Lremoved_finetuned.pth.tar
# INFO:root:=> Checkpoint contents:
# ╒═══════════════════╤═════════════╤════════════════╕
# │ Key               │ Type        │ Value          │
# ╞═══════════════════╪═════════════╪════════════════╡
# │ arch              │ str         │ resnet20_cifar │
# ├───────────────────┼─────────────┼────────────────┤
# │ best_top1         │ float       │ 94.24          │
# ├───────────────────┼─────────────┼────────────────┤
# │ compression_sched │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ epoch             │ int         │ 249            │
# ├───────────────────┼─────────────┼────────────────┤
# │ optimizer         │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ state_dict        │ OrderedDict │                │
# ╘═══════════════════╧═════════════╧════════════════╛
#
# INFO:root:Loaded compression schedule from checkpoint (epoch 249)
# WARNING:root:Optimizer could not be loaded from checkpoint.
# INFO:root:=> loaded checkpoint '/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_4D_regularized_5Lremoved_finetuned.pth.tar' (epoch 249)
# INFO:__main__:
# WeightWatcher v0.1.2 by Calculation Consulting
# Analyze weight matrices of Deep Neural Networks
# https://calculationconsulting.com/
# python      version 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.15.3
# tensforflow version 1.10.1
# keras       version 2.2.2
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 2.5295395851135254, max: 7.4775214195251465, avg: 5.17536735534668
# INFO:__main__:Norm compound: min: 2.6622424125671387, max: 6.906456470489502, avg: 5.175367832183838
# INFO:__main__:LogNorm: min: 0.4030414819717407, max: 0.8737576603889465, avg: 0.6895095109939575
# INFO:__main__:LogNorm compound: min: 0.42511019110679626, max: 0.8387784361839294, avg: 0.6895094513893127
# INFO:__main__:Alpha: min: 1.547911240590813, max: 6.215031447044829, avg: 2.9283534919514183
# INFO:__main__:Alpha compound: min: 1.5677253169822416, max: 3.4840509191567137, avg: 2.9283534919514183
# INFO:__main__:Alpha Weighted: min: -0.20133656185538537, max: 2.4306535014449824, avg: 1.0113115613133257
# INFO:__main__:Alpha Weighted compound: min: -0.13598742569002653, max: 1.7519840569712983, avg: 1.0113115613133257
# INFO:__main__:Spectral Norm: min: 0.0, max: 40.63998031616211, avg: 2.2757227420806885
# INFO:__main__:Spectral Norm compound: min: 0.0, max: 40.63998031616211, avg: 4.141265392303467
# INFO:__main__:Softrank: min: 1.5181262493133545, max: 3.7335708141326904, avg: 2.501386880874634
# INFO:__main__:Softrank compound: min: 1.7983059883117676, max: 3.251925468444824, avg: 2.501387119293213
# INFO:__main__:Softrank Log: min: 0.18130789697170258, max: 0.5721244215965271, avg: 0.3834882378578186
# INFO:__main__:Softrank Log compound: min: 0.253418892621994, max: 0.5117360949516296, avg: 0.383488267660141
# INFO:__main__:Softrank Log Ratio: min: -10.531365394592285, max: 16.531902313232422, avg: 1.2393858432769775
# INFO:__main__:Softrank Log Ratio compound: min: -5.48734188079834, max: 6.824556827545166, avg: 1.2393858432769775
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 2.5295395851135254, max: 7.4775214195251465, avg: 5.17536735534668
# INFO:__main__:Norm compound: min: 2.6622424125671387, max: 6.906456470489502, avg: 5.175367832183838
# INFO:__main__:LogNorm: min: 0.4030414819717407, max: 0.8737576603889465, avg: 0.6895095109939575
# INFO:__main__:LogNorm compound: min: 0.42511019110679626, max: 0.8387784361839294, avg: 0.6895094513893127
# INFO:__main__:Alpha: min: 1.547911240590813, max: 6.215031447044829, avg: 2.9283534919514183
# INFO:__main__:Alpha compound: min: 1.5677253169822416, max: 3.4840509191567137, avg: 2.9283534919514183
# INFO:__main__:Alpha Weighted: min: -0.20133656185538537, max: 2.4306535014449824, avg: 1.0113115613133257
# INFO:__main__:Alpha Weighted compound: min: -0.13598742569002653, max: 1.7519840569712983, avg: 1.0113115613133257
# INFO:__main__:Spectral Norm: min: 0.0, max: 40.63998031616211, avg: 2.2757227420806885
# INFO:__main__:Spectral Norm compound: min: 0.0, max: 40.63998031616211, avg: 4.141265392303467
# INFO:__main__:Softrank: min: 1.5181262493133545, max: 3.7335708141326904, avg: 2.501386880874634
# INFO:__main__:Softrank compound: min: 1.7983059883117676, max: 3.251925468444824, avg: 2.501387119293213
# INFO:__main__:Softrank Log: min: 0.18130789697170258, max: 0.5721244215965271, avg: 0.3834882378578186
# INFO:__main__:Softrank Log compound: min: 0.253418892621994, max: 0.5117360949516296, avg: 0.383488267660141
# INFO:__main__:Softrank Log Ratio: min: -10.531365394592285, max: 16.531902313232422, avg: 1.2393858432769775
# INFO:__main__:Softrank Log Ratio compound: min: -5.48734188079834, max: 6.824556827545166, avg: 1.2393858432769775
# INFO:__main__:checkpoint_trained_channel_regularized_resnet20.pth.tar
# INFO:root:=> creating resnet20_cifar model for CIFAR10
# INFO:root:=> loading checkpoint /Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_channel_regularized_resnet20.pth.tar
# INFO:root:=> Checkpoint contents:
# ╒═══════════════════╤═════════════╤════════════════╕
# │ Key               │ Type        │ Value          │
# ╞═══════════════════╪═════════════╪════════════════╡
# │ arch              │ str         │ resnet20_cifar │
# ├───────────────────┼─────────────┼────────────────┤
# │ best_top1         │ float       │ 91.42          │
# ├───────────────────┼─────────────┼────────────────┤
# │ compression_sched │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ epoch             │ int         │ 179            │
# ├───────────────────┼─────────────┼────────────────┤
# │ optimizer         │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ state_dict        │ OrderedDict │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ thinning_recipes  │ list        │                │
# ╘═══════════════════╧═════════════╧════════════════╛
#
# INFO:root:Loaded compression schedule from checkpoint (epoch 179)
# INFO:root:Loaded a thinning recipe from the checkpoint
# INFO:distiller.thinning:Executed 1 recipes
# WARNING:root:Optimizer could not be loaded from checkpoint.
# INFO:root:=> loaded checkpoint '/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_channel_regularized_resnet20.pth.tar' (epoch 179)
# INFO:__main__:
# WeightWatcher v0.1.2 by Calculation Consulting
# Analyze weight matrices of Deep Neural Networks
# https://calculationconsulting.com/
# python      version 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.15.3
# tensforflow version 1.10.1
# keras       version 2.2.2
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 0.9616986513137817, max: 6.399134635925293, avg: 3.613520622253418
# INFO:__main__:Norm compound: min: 0.9885376691818237, max: 6.121191024780273, avg: 3.613520383834839
# INFO:__main__:LogNorm: min: -0.0169609934091568, max: 0.8061212301254272, avg: 0.4641056954860687
# INFO:__main__:LogNorm compound: min: -0.005092449486255646, max: 0.7863892316818237, avg: 0.4641056954860687
# INFO:__main__:Alpha: min: 1.6516568185690215, max: 6.082362847151547, avg: 2.8896926333804753
# INFO:__main__:Alpha compound: min: 2.0766900065121576, max: 3.594425464997663, avg: 2.8896926333804744
# INFO:__main__:Alpha Weighted: min: -4.147062786895681, max: 2.5657147722962312, avg: -0.29591712414495
# INFO:__main__:Alpha Weighted compound: min: -3.014929429034478, max: 1.6602932552798195, avg: -0.29591712414495
# INFO:__main__:Spectral Norm: min: 0.015162433497607708, max: 47.922122955322266, avg: 1.986101508140564
# INFO:__main__:Spectral Norm compound: min: 0.018178312107920647, max: 47.922122955322266, avg: 4.408066272735596
# INFO:__main__:Softrank: min: 1.6727925539016724, max: 13.036584854125977, avg: 5.001067161560059
# INFO:__main__:Softrank compound: min: 1.9905667304992676, max: 11.853692054748535, avg: 5.001067161560059
# INFO:__main__:Softrank Log: min: 0.22344209253787994, max: 1.115163803100586, avg: 0.5815376043319702
# INFO:__main__:Softrank Log compound: min: 0.297432541847229, max: 1.0730504989624023, avg: 0.5815376043319702
# INFO:__main__:Softrank Log Ratio: min: -0.45843324065208435, max: 5.235281467437744, avg: 1.266338586807251
# INFO:__main__:Softrank Log Ratio compound: min: -0.3469788730144501, max: 3.24133563041687, avg: 1.266338586807251
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 0.9616986513137817, max: 6.399134635925293, avg: 3.613520622253418
# INFO:__main__:Norm compound: min: 0.9885376691818237, max: 6.121191024780273, avg: 3.613520383834839
# INFO:__main__:LogNorm: min: -0.0169609934091568, max: 0.8061212301254272, avg: 0.4641056954860687
# INFO:__main__:LogNorm compound: min: -0.005092449486255646, max: 0.7863892316818237, avg: 0.4641056954860687
# INFO:__main__:Alpha: min: 1.6516568185690215, max: 6.082362847151547, avg: 2.8896926333804753
# INFO:__main__:Alpha compound: min: 2.0766900065121576, max: 3.594425464997663, avg: 2.8896926333804744
# INFO:__main__:Alpha Weighted: min: -4.147062786895681, max: 2.5657147722962312, avg: -0.29591712414495
# INFO:__main__:Alpha Weighted compound: min: -3.014929429034478, max: 1.6602932552798195, avg: -0.29591712414495
# INFO:__main__:Spectral Norm: min: 0.015162433497607708, max: 47.922122955322266, avg: 1.986101508140564
# INFO:__main__:Spectral Norm compound: min: 0.018178312107920647, max: 47.922122955322266, avg: 4.408066272735596
# INFO:__main__:Softrank: min: 1.6727925539016724, max: 13.036584854125977, avg: 5.001067161560059
# INFO:__main__:Softrank compound: min: 1.9905667304992676, max: 11.853692054748535, avg: 5.001067161560059
# INFO:__main__:Softrank Log: min: 0.22344209253787994, max: 1.115163803100586, avg: 0.5815376043319702
# INFO:__main__:Softrank Log compound: min: 0.297432541847229, max: 1.0730504989624023, avg: 0.5815376043319702
# INFO:__main__:Softrank Log Ratio: min: -0.45843324065208435, max: 5.235281467437744, avg: 1.266338586807251
# INFO:__main__:Softrank Log Ratio compound: min: -0.3469788730144501, max: 3.24133563041687, avg: 1.266338586807251
# INFO:__main__:checkpoint_trained_channel_regularized_resnet20_finetuned.pth.tar
# INFO:root:=> creating resnet20_cifar model for CIFAR10
# INFO:root:=> loading checkpoint /Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_channel_regularized_resnet20_finetuned.pth.tar
# INFO:root:=> Checkpoint contents:
# ╒═══════════════════╤═════════════╤════════════════╕
# │ Key               │ Type        │ Value          │
# ╞═══════════════════╪═════════════╪════════════════╡
# │ arch              │ str         │ resnet20_cifar │
# ├───────────────────┼─────────────┼────────────────┤
# │ best_top1         │ float       │ 91.42          │
# ├───────────────────┼─────────────┼────────────────┤
# │ compression_sched │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ epoch             │ int         │ 277            │
# ├───────────────────┼─────────────┼────────────────┤
# │ optimizer         │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ state_dict        │ OrderedDict │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ thinning_recipes  │ list        │                │
# ╘═══════════════════╧═════════════╧════════════════╛
# INFO:root:Loaded compression schedule from checkpoint (epoch 277)
# INFO:root:Loaded a thinning recipe from the checkpoint
# INFO:distiller.thinning:Executed 1 recipes
# WARNING:root:Optimizer could not be loaded from checkpoint.
# INFO:root:=> loaded checkpoint '/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_channel_regularized_resnet20_finetuned.pth.tar' (epoch 277)
# INFO:__main__:
# WeightWatcher v0.1.2 by Calculation Consulting
# Analyze weight matrices of Deep Neural Networks
# https://calculationconsulting.com/
# python      version 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.15.3
# tensforflow version 1.10.1
# keras       version 2.2.2
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 3.841867208480835, max: 6.646107196807861, avg: 5.106140613555908
# INFO:__main__:Norm compound: min: 4.048958778381348, max: 6.259210586547852, avg: 5.106141090393066
# INFO:__main__:LogNorm: min: 0.5845423340797424, max: 0.822567343711853, avg: 0.7017643451690674
# INFO:__main__:LogNorm compound: min: 0.6071060299873352, max: 0.7961605191230774, avg: 0.7017642855644226
# INFO:__main__:Alpha: min: 1.6872989739129702, max: 8.84542760870864, avg: 2.8356899915597458
# INFO:__main__:Alpha compound: min: 2.5534866905538114, max: 3.03507372097255, avg: 2.835689991559746
# INFO:__main__:Alpha Weighted: min: 0.17436023361923977, max: 2.0723672977638854, avg: 1.0363728869834337
# INFO:__main__:Alpha Weighted compound: min: 0.5372022756323082, max: 1.3420071327590348, avg: 1.0363728869834337
# INFO:__main__:Spectral Norm: min: 0.4599851667881012, max: 46.68931198120117, avg: 2.578279972076416
# INFO:__main__:Spectral Norm compound: min: 0.7482590079307556, max: 46.68931198120117, avg: 4.803412914276123
# INFO:__main__:Softrank: min: 1.6909968852996826, max: 3.0991744995117188, avg: 2.215278387069702
# INFO:__main__:Softrank compound: min: 1.920041799545288, max: 2.5637564659118652, avg: 2.215278148651123
# INFO:__main__:Softrank Log: min: 0.22814281284809113, max: 0.4912460446357727, avg: 0.34105345606803894
# INFO:__main__:Softrank Log compound: min: 0.2821265459060669, max: 0.40338680148124695, avg: 0.34105348587036133
# INFO:__main__:Softrank Log Ratio: min: 1.4387426376342773, max: 5.965426445007324, avg: 2.2159907817840576
# INFO:__main__:Softrank Log Ratio compound: min: 1.6035535335540771, max: 3.418213129043579, avg: 2.2159905433654785
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 3.841867208480835, max: 6.646107196807861, avg: 5.106140613555908
# INFO:__main__:Norm compound: min: 4.048958778381348, max: 6.259210586547852, avg: 5.106141090393066
# INFO:__main__:LogNorm: min: 0.5845423340797424, max: 0.822567343711853, avg: 0.7017643451690674
# INFO:__main__:LogNorm compound: min: 0.6071060299873352, max: 0.7961605191230774, avg: 0.7017642855644226
# INFO:__main__:Alpha: min: 1.6872989739129702, max: 8.84542760870864, avg: 2.8356899915597458
# INFO:__main__:Alpha compound: min: 2.5534866905538114, max: 3.03507372097255, avg: 2.835689991559746
# INFO:__main__:Alpha Weighted: min: 0.17436023361923977, max: 2.0723672977638854, avg: 1.0363728869834337
# INFO:__main__:Alpha Weighted compound: min: 0.5372022756323082, max: 1.3420071327590348, avg: 1.0363728869834337
# INFO:__main__:Spectral Norm: min: 0.4599851667881012, max: 46.68931198120117, avg: 2.578279972076416
# INFO:__main__:Spectral Norm compound: min: 0.7482590079307556, max: 46.68931198120117, avg: 4.803412914276123
# INFO:__main__:Softrank: min: 1.6909968852996826, max: 3.0991744995117188, avg: 2.215278387069702
# INFO:__main__:Softrank compound: min: 1.920041799545288, max: 2.5637564659118652, avg: 2.215278148651123
# INFO:__main__:Softrank Log: min: 0.22814281284809113, max: 0.4912460446357727, avg: 0.34105345606803894
# INFO:__main__:Softrank Log compound: min: 0.2821265459060669, max: 0.40338680148124695, avg: 0.34105348587036133
# INFO:__main__:Softrank Log Ratio: min: 1.4387426376342773, max: 5.965426445007324, avg: 2.2159907817840576
# INFO:__main__:Softrank Log Ratio compound: min: 1.6035535335540771, max: 3.418213129043579, avg: 2.2159905433654785
# INFO:__main__:checkpoint_trained_dense.pth.tar
# INFO:root:=> creating resnet20_cifar model for CIFAR10
# INFO:root:=> loading checkpoint /Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_dense.pth.tar
# INFO:root:=> Checkpoint contents:
# ╒═══════════════════╤═════════════╤════════════════╕
# │ Key               │ Type        │ Value          │
# ╞═══════════════════╪═════════════╪════════════════╡
# │ arch              │ str         │ resnet20_cifar │
# ├───────────────────┼─────────────┼────────────────┤
# │ best_top1         │ float       │ 92.54          │
# ├───────────────────┼─────────────┼────────────────┤
# │ compression_sched │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ epoch             │ int         │ 179            │
# ├───────────────────┼─────────────┼────────────────┤
# │ optimizer         │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ state_dict        │ OrderedDict │                │
# ╘═══════════════════╧═════════════╧════════════════╛
#
# INFO:root:Loaded compression schedule from checkpoint (epoch 179)
# WARNING:root:Optimizer could not be loaded from checkpoint.
# INFO:root:=> loaded checkpoint '/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_dense.pth.tar' (epoch 179)
# INFO:__main__:
# WeightWatcher v0.1.2 by Calculation Consulting
# Analyze weight matrices of Deep Neural Networks
# https://calculationconsulting.com/
# python      version 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.15.3
# tensforflow version 1.10.1
# keras       version 2.2.2
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 2.9887137413024902, max: 6.565643310546875, avg: 5.155532360076904
# INFO:__main__:Norm compound: min: 3.2488815784454346, max: 6.177272796630859, avg: 5.1555328369140625
# INFO:__main__:LogNorm: min: 0.47548431158065796, max: 0.8172773122787476, avg: 0.701586127281189
# INFO:__main__:LogNorm compound: min: 0.5113270282745361, max: 0.7905223965644836, avg: 0.701586127281189
# INFO:__main__:Alpha: min: 1.5785914811416748, max: 8.051494462627435, avg: 3.2900311199677748
# INFO:__main__:Alpha compound: min: 1.602282325285679, max: 4.418098361155243, avg: 3.290031119967775
# INFO:__main__:Alpha Weighted: min: 0.08285118040412506, max: 4.080548230727559, avg: 1.2619669891538585
# INFO:__main__:Alpha Weighted compound: min: 0.14628637935188438, max: 2.2707105499266667, avg: 1.2619669891538587
# INFO:__main__:Spectral Norm: min: 0.6770037412643433, max: 38.83589553833008, avg: 2.4234611988067627
# INFO:__main__:Spectral Norm compound: min: 0.9891248345375061, max: 38.83589553833008, avg: 4.146236896514893
# INFO:__main__:Softrank: min: 1.617583990097046, max: 3.063535690307617, avg: 2.3229050636291504
# INFO:__main__:Softrank compound: min: 1.8773165941238403, max: 2.6403019428253174, avg: 2.3229048252105713
# INFO:__main__:Softrank Log: min: 0.20886683464050293, max: 0.4862229526042938, avg: 0.3598952293395996
# INFO:__main__:Softrank Log compound: min: 0.27264848351478577, max: 0.4203161299228668, avg: 0.3598952293395996
# INFO:__main__:Softrank Log Ratio: min: 1.380421757698059, max: 10.050775527954102, avg: 2.84612774848938
# INFO:__main__:Softrank Log Ratio compound: min: 1.5305171012878418, max: 6.349797248840332, avg: 2.84612774848938
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 2.9887137413024902, max: 6.565643310546875, avg: 5.155532360076904
# INFO:__main__:Norm compound: min: 3.2488815784454346, max: 6.177272796630859, avg: 5.1555328369140625
# INFO:__main__:LogNorm: min: 0.47548431158065796, max: 0.8172773122787476, avg: 0.701586127281189
# INFO:__main__:LogNorm compound: min: 0.5113270282745361, max: 0.7905223965644836, avg: 0.701586127281189
# INFO:__main__:Alpha: min: 1.5785914811416748, max: 8.051494462627435, avg: 3.2900311199677748
# INFO:__main__:Alpha compound: min: 1.602282325285679, max: 4.418098361155243, avg: 3.290031119967775
# INFO:__main__:Alpha Weighted: min: 0.08285118040412506, max: 4.080548230727559, avg: 1.2619669891538585
# INFO:__main__:Alpha Weighted compound: min: 0.14628637935188438, max: 2.2707105499266667, avg: 1.2619669891538587
# INFO:__main__:Spectral Norm: min: 0.6770037412643433, max: 38.83589553833008, avg: 2.4234611988067627
# INFO:__main__:Spectral Norm compound: min: 0.9891248345375061, max: 38.83589553833008, avg: 4.146236896514893
# INFO:__main__:Softrank: min: 1.617583990097046, max: 3.063535690307617, avg: 2.3229050636291504
# INFO:__main__:Softrank compound: min: 1.8773165941238403, max: 2.6403019428253174, avg: 2.3229048252105713
# INFO:__main__:Softrank Log: min: 0.20886683464050293, max: 0.4862229526042938, avg: 0.3598952293395996
# INFO:__main__:Softrank Log compound: min: 0.27264848351478577, max: 0.4203161299228668, avg: 0.3598952293395996
# INFO:__main__:Softrank Log Ratio: min: 1.380421757698059, max: 10.050775527954102, avg: 2.84612774848938
# INFO:__main__:Softrank Log Ratio compound: min: 1.5305171012878418, max: 6.349797248840332, avg: 2.84612774848938
# INFO:__main__:checkpoint_trained_ch_regularized_dense.pth.tar
# INFO:root:=> creating resnet20_cifar model for CIFAR10
# INFO:root:=> loading checkpoint /Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_ch_regularized_dense.pth.tar
# INFO:root:=> Checkpoint contents:
# ╒═══════════════════╤═════════════╤════════════════╕
# │ Key               │ Type        │ Value          │
# ╞═══════════════════╪═════════════╪════════════════╡
# │ arch              │ str         │ resnet20_cifar │
# ├───────────────────┼─────────────┼────────────────┤
# │ best_top1         │ float       │ 91.7           │
# ├───────────────────┼─────────────┼────────────────┤
# │ compression_sched │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ epoch             │ int         │ 179            │
# ├───────────────────┼─────────────┼────────────────┤
# │ optimizer         │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ state_dict        │ OrderedDict │                │
# ╘═══════════════════╧═════════════╧════════════════╛
#
# INFO:root:Loaded compression schedule from checkpoint (epoch 179)
# WARNING:root:Optimizer could not be loaded from checkpoint.
# INFO:root:=> loaded checkpoint '/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_ch_regularized_dense.pth.tar' (epoch 179)
# INFO:__main__:
# WeightWatcher v0.1.2 by Calculation Consulting
# Analyze weight matrices of Deep Neural Networks
# https://calculationconsulting.com/
# python      version 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.15.3
# tensforflow version 1.10.1
# keras       version 2.2.2
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 0.9492148756980896, max: 6.796518802642822, avg: 3.640742301940918
# INFO:__main__:Norm compound: min: 0.9812278747558594, max: 6.535299777984619, avg: 3.640742540359497
# INFO:__main__:LogNorm: min: -0.022635463625192642, max: 0.832286536693573, avg: 0.46435806155204773
# INFO:__main__:LogNorm compound: min: -0.008332151919603348, max: 0.8149301409721375, avg: 0.46435803174972534
# INFO:__main__:Alpha: min: 1.7259189729097169, max: 6.724975714627756, avg: 2.9501328439417067
# INFO:__main__:Alpha compound: min: 2.4584588007159707, max: 3.8049272187199707, avg: 2.9501328439417054
# INFO:__main__:Alpha Weighted: min: -6.787172421264657, max: 2.9439692310490386, avg: -0.42766253027950746
# INFO:__main__:Alpha Weighted compound: min: -3.748983798004493, max: 1.749244815886357, avg: -0.4276625302795076
# INFO:__main__:Spectral Norm: min: 0.023620344698429108, max: 49.74582290649414, avg: 2.0559918880462646
# INFO:__main__:Spectral Norm compound: min: 0.029588665813207626, max: 49.74582290649414, avg: 4.5758256912231445
# INFO:__main__:Softrank: min: 1.7277911901474, max: 10.574136734008789, avg: 4.526306629180908
# INFO:__main__:Softrank compound: min: 1.9695194959640503, max: 9.513106346130371, avg: 4.52630615234375
# INFO:__main__:Softrank Log: min: 0.23749125003814697, max: 1.0242449045181274, avg: 0.5649740099906921
# INFO:__main__:Softrank Log compound: min: 0.292664110660553, max: 0.9773926138877869, avg: 0.5649740099906921
# INFO:__main__:Softrank Log Ratio: min: -0.40579739212989807, max: 3.862175703048706, avg: 1.243118166923523
# INFO:__main__:Softrank Log Ratio compound: min: -0.3422672748565674, max: 2.8819851875305176, avg: 1.2431180477142334
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 0.9492148756980896, max: 6.796518802642822, avg: 3.640742301940918
# INFO:__main__:Norm compound: min: 0.9812278747558594, max: 6.535299777984619, avg: 3.640742540359497
# INFO:__main__:LogNorm: min: -0.022635463625192642, max: 0.832286536693573, avg: 0.46435806155204773
# INFO:__main__:LogNorm compound: min: -0.008332151919603348, max: 0.8149301409721375, avg: 0.46435803174972534
# INFO:__main__:Alpha: min: 1.7259189729097169, max: 6.724975714627756, avg: 2.9501328439417067
# INFO:__main__:Alpha compound: min: 2.4584588007159707, max: 3.8049272187199707, avg: 2.9501328439417054
# INFO:__main__:Alpha Weighted: min: -6.787172421264657, max: 2.9439692310490386, avg: -0.42766253027950746
# INFO:__main__:Alpha Weighted compound: min: -3.748983798004493, max: 1.749244815886357, avg: -0.4276625302795076
# INFO:__main__:Spectral Norm: min: 0.023620344698429108, max: 49.74582290649414, avg: 2.0559918880462646
# INFO:__main__:Spectral Norm compound: min: 0.029588665813207626, max: 49.74582290649414, avg: 4.5758256912231445
# INFO:__main__:Softrank: min: 1.7277911901474, max: 10.574136734008789, avg: 4.526306629180908
# INFO:__main__:Softrank compound: min: 1.9695194959640503, max: 9.513106346130371, avg: 4.52630615234375
# INFO:__main__:Softrank Log: min: 0.23749125003814697, max: 1.0242449045181274, avg: 0.5649740099906921
# INFO:__main__:Softrank Log compound: min: 0.292664110660553, max: 0.9773926138877869, avg: 0.5649740099906921
# INFO:__main__:Softrank Log Ratio: min: -0.40579739212989807, max: 3.862175703048706, avg: 1.243118166923523
# INFO:__main__:Softrank Log Ratio compound: min: -0.3422672748565674, max: 2.8819851875305176, avg: 1.2431180477142334

# %%
results
# Out:
# {'checkpoint_trained_4D_regularized_5Lremoved.pth.tar': {'norm': 4.3157954,
#   'norm_compound': 4.315795,
#   'lognorm': 0.51755166,
#   'lognorm_compound': 0.5175516,
#   'alpha': 3.196053477405699,
#   'alpha_compound': 3.196053477405699,
#   'alpha_weighted': 0.3071941264704492,
#   'alpha_weighted_compound': 0.30719412647044925,
#   'spectralnorm': 2.176673,
#   'spectralnorm_compound': 4.2567616,
#   'softrank': 4.5645304,
#   'softrank_compound': 4.56453,
#   'softranklog': 0.5427221,
#   'softranklog_compound': 0.5427221,
#   'softranklogratio': 0.87940735,
#   'softranklogratio_compound': 0.8794072,
#   'accuracy': 90.62},
#  'checkpoint_trained_4D_regularized_5Lremoved_finetuned.pth.tar': {'norm': 5.1753674,
#   'norm_compound': 5.175368,
#   'lognorm': 0.6895095,
#   'lognorm_compound': 0.68950945,
#   'alpha': 2.9283534919514183,
#   'alpha_compound': 2.9283534919514183,
#   'alpha_weighted': 1.0113115613133257,
#   'alpha_weighted_compound': 1.0113115613133257,
#   'spectralnorm': 2.2757227,
#   'spectralnorm_compound': 4.1412654,
#   'softrank': 2.501387,
#   'softrank_compound': 2.5013871,
#   'softranklog': 0.38348824,
#   'softranklog_compound': 0.38348827,
#   'softranklogratio': 1.2393858,
#   'softranklogratio_compound': 1.2393858,
#   'accuracy': 94.24},
#  'checkpoint_trained_channel_regularized_resnet20.pth.tar': {'norm': 3.6135206,
#   'norm_compound': 3.6135204,
#   'lognorm': 0.4641057,
#   'lognorm_compound': 0.4641057,
#   'alpha': 2.8896926333804753,
#   'alpha_compound': 2.8896926333804744,
#   'alpha_weighted': -0.29591712414495,
#   'alpha_weighted_compound': -0.29591712414495,
#   'spectralnorm': 1.9861015,
#   'spectralnorm_compound': 4.4080663,
#   'softrank': 5.001067,
#   'softrank_compound': 5.001067,
#   'softranklog': 0.5815376,
#   'softranklog_compound': 0.5815376,
#   'softranklogratio': 1.2663386,
#   'softranklogratio_compound': 1.2663386,
#   'accuracy': 91.42},
#  'checkpoint_trained_channel_regularized_resnet20_finetuned.pth.tar': {'norm': 5.1061406,
#   'norm_compound': 5.106141,
#   'lognorm': 0.70176435,
#   'lognorm_compound': 0.7017643,
#   'alpha': 2.8356899915597458,
#   'alpha_compound': 2.835689991559746,
#   'alpha_weighted': 1.0363728869834337,
#   'alpha_weighted_compound': 1.0363728869834337,
#   'spectralnorm': 2.57828,
#   'spectralnorm_compound': 4.803413,
#   'softrank': 2.2152784,
#   'softrank_compound': 2.2152781,
#   'softranklog': 0.34105346,
#   'softranklog_compound': 0.3410535,
#   'softranklogratio': 2.2159908,
#   'softranklogratio_compound': 2.2159905,
#   'accuracy': 91.42},
#  'checkpoint_trained_dense.pth.tar': {'norm': 5.1555324,
#   'norm_compound': 5.155533,
#   'lognorm': 0.7015861,
#   'lognorm_compound': 0.7015861,
#   'alpha': 3.2900311199677748,
#   'alpha_compound': 3.290031119967775,
#   'alpha_weighted': 1.2619669891538585,
#   'alpha_weighted_compound': 1.2619669891538587,
#   'spectralnorm': 2.4234612,
#   'spectralnorm_compound': 4.146237,
#   'softrank': 2.322905,
#   'softrank_compound': 2.3229048,
#   'softranklog': 0.35989523,
#   'softranklog_compound': 0.35989523,
#   'softranklogratio': 2.8461277,
#   'softranklogratio_compound': 2.8461277,
#   'accuracy': 92.54},
#  'checkpoint_trained_ch_regularized_dense.pth.tar': {'norm': 3.6407423,
#   'norm_compound': 3.6407425,
#   'lognorm': 0.46435806,
#   'lognorm_compound': 0.46435803,
#   'alpha': 2.9501328439417067,
#   'alpha_compound': 2.9501328439417054,
#   'alpha_weighted': -0.42766253027950746,
#   'alpha_weighted_compound': -0.4276625302795076,
#   'spectralnorm': 2.055992,
#   'spectralnorm_compound': 4.5758257,
#   'softrank': 4.5263066,
#   'softrank_compound': 4.526306,
#   'softranklog': 0.564974,
#   'softranklog_compound': 0.564974,
#   'softranklogratio': 1.2431182,
#   'softranklogratio_compound': 1.243118,
#   'accuracy': 91.7}}

# %%
metrics = ['lognorm', 'alpha', 'alpha_weighted', 'softrank', 'spectralnorm'] # 'lambda_max']
colors = ['blue', 'cyan', 'red', 'orange', 'green', 'lightgreen']
for metric in metrics:
    marker_size = 75
    plt.rcParams['figure.figsize'] = [10,10]
    matplotlib.rcParams.update({'font.size': 16})
    legend_prop={'size':12}

    ic = 0
    for file, result in results.items():
        file = file[len("checkpoint_trained_"):]
        plt.scatter(result[metric], 100.0-result['accuracy'], label=file, s=marker_size, color=colors[ic]);
        ic+=1
        
    plt.xlabel(metric)
    plt.ylabel("Top 1 Error")

    plt.legend(prop=legend_prop)

    plt.show();

# %%
df = watcher.get_details().set_index('layer_id')
# Out:
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 2.5295395851135254, max: 7.4775214195251465, avg: 5.17536735534668
# INFO:__main__:Norm compound: min: 2.6622424125671387, max: 6.906456470489502, avg: 5.175367832183838
# INFO:__main__:LogNorm: min: 0.4030414819717407, max: 0.8737576603889465, avg: 0.6895095109939575
# INFO:__main__:LogNorm compound: min: 0.42511019110679626, max: 0.8387784361839294, avg: 0.6895094513893127
# INFO:__main__:Alpha: min: 1.547911240590813, max: 6.215031447044829, avg: 2.9283534919514183
# INFO:__main__:Alpha compound: min: 1.5677253169822416, max: 3.4840509191567137, avg: 2.9283534919514183
# INFO:__main__:Alpha Weighted: min: -0.20133656185538537, max: 2.4306535014449824, avg: 1.0113115613133257
# INFO:__main__:Alpha Weighted compound: min: -0.13598742569002653, max: 1.7519840569712983, avg: 1.0113115613133257

# %%
watcher.compute_details()[:-1].dropna(axis=1,how='all').set_index("layer_id")
# Out:
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 2.5295395851135254, max: 7.4775214195251465, avg: 5.17536735534668
# INFO:__main__:Norm compound: min: 2.6622424125671387, max: 6.906456470489502, avg: 5.175367832183838
# INFO:__main__:LogNorm: min: 0.4030414819717407, max: 0.8737576603889465, avg: 0.6895095109939575
# INFO:__main__:LogNorm compound: min: 0.42511019110679626, max: 0.8387784361839294, avg: 0.6895094513893127
# INFO:__main__:Alpha: min: 1.547911240590813, max: 6.215031447044829, avg: 2.9283534919514183
# INFO:__main__:Alpha compound: min: 1.5677253169822416, max: 3.4840509191567137, avg: 2.9283534919514183
# INFO:__main__:Alpha Weighted: min: -0.20133656185538537, max: 2.4306535014449824, avg: 1.0113115613133257
# INFO:__main__:Alpha Weighted compound: min: -0.13598742569002653, max: 1.7519840569712983, avg: 1.0113115613133257
#          layer_type    N    M slice slice_count        level      comment  \
# layer_id
# 0               NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 1            CONV2D   16    3     0         NaN  LEVEL.SLICE  Slice level
# 1            CONV2D   16    3     1         NaN  LEVEL.SLICE  Slice level
# 1            CONV2D   16    3     2         NaN  LEVEL.SLICE  Slice level
# 1            CONV2D   16    3     3         NaN  LEVEL.SLICE  Slice level
# 1            CONV2D   16    3     4         NaN  LEVEL.SLICE  Slice level
# 1            CONV2D   16    3     5         NaN  LEVEL.SLICE  Slice level
# 1            CONV2D   16    3     6         NaN  LEVEL.SLICE  Slice level
# 1            CONV2D   16    3     7         NaN  LEVEL.SLICE  Slice level
# 1            CONV2D   16    3     8         NaN  LEVEL.SLICE  Slice level
# 1            CONV2D  144   27   NaN           9  LEVEL.LAYER  Layer level
# 2               NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 3               NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 4               NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 5               NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 6            CONV2D   16   16     0         NaN  LEVEL.SLICE  Slice level
# 6            CONV2D   16   16     1         NaN  LEVEL.SLICE  Slice level
# 6            CONV2D   16   16     2         NaN  LEVEL.SLICE  Slice level
# 6            CONV2D   16   16     3         NaN  LEVEL.SLICE  Slice level
# 6            CONV2D   16   16     4         NaN  LEVEL.SLICE  Slice level
# 6            CONV2D   16   16     5         NaN  LEVEL.SLICE  Slice level
# 6            CONV2D   16   16     6         NaN  LEVEL.SLICE  Slice level
# 6            CONV2D   16   16     7         NaN  LEVEL.SLICE  Slice level
# 6            CONV2D   16   16     8         NaN  LEVEL.SLICE  Slice level
# 6            CONV2D  144  144   NaN           9  LEVEL.LAYER  Layer level
# 7               NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 8               NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 9            CONV2D   16   16     0         NaN  LEVEL.SLICE  Slice level
# 9            CONV2D   16   16     1         NaN  LEVEL.SLICE  Slice level
# 9            CONV2D   16   16     2         NaN  LEVEL.SLICE  Slice level
# ...             ...  ...  ...   ...         ...          ...          ...
# 67              NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 68              NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 69              NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 70           CONV2D   64   64     0         NaN  LEVEL.SLICE  Slice level
# 70           CONV2D   64   64     1         NaN  LEVEL.SLICE  Slice level
# 70           CONV2D   64   64     2         NaN  LEVEL.SLICE  Slice level
# 70           CONV2D   64   64     3         NaN  LEVEL.SLICE  Slice level
# 70           CONV2D   64   64     4         NaN  LEVEL.SLICE  Slice level
# 70           CONV2D   64   64     5         NaN  LEVEL.SLICE  Slice level
# 70           CONV2D   64   64     6         NaN  LEVEL.SLICE  Slice level
# 70           CONV2D   64   64     7         NaN  LEVEL.SLICE  Slice level
# 70           CONV2D   64   64     8         NaN  LEVEL.SLICE  Slice level
# 70           CONV2D  576  576   NaN           9  LEVEL.LAYER  Layer level
# 71              NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 72              NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 73           CONV2D   64   64     0         NaN  LEVEL.SLICE  Slice level
# 73           CONV2D   64   64     1         NaN  LEVEL.SLICE  Slice level
# 73           CONV2D   64   64     2         NaN  LEVEL.SLICE  Slice level
# 73           CONV2D   64   64     3         NaN  LEVEL.SLICE  Slice level
# 73           CONV2D   64   64     4         NaN  LEVEL.SLICE  Slice level
# 73           CONV2D   64   64     5         NaN  LEVEL.SLICE  Slice level
# 73           CONV2D   64   64     6         NaN  LEVEL.SLICE  Slice level
# 73           CONV2D   64   64     7         NaN  LEVEL.SLICE  Slice level
# 73           CONV2D   64   64     8         NaN  LEVEL.SLICE  Slice level
# 73           CONV2D  576  576   NaN           9  LEVEL.LAYER  Layer level
# 74              NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 75              NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 76              NaN    0    0   NaN           0  LEVEL.LAYER  Layer level
# 77            DENSE   64   10     0         NaN  LEVEL.SLICE  Slice level
# 77            DENSE   64   10   NaN           1  LEVEL.LAYER  Layer level
#
#              norm   lognorm    alpha alpha_weighted
# layer_id
# 0             NaN       NaN      NaN            NaN
# 1             NaN       NaN      NaN            NaN
# 1             NaN       NaN      NaN            NaN
# 1             NaN       NaN      NaN            NaN
# 1             NaN       NaN      NaN            NaN
# 1             NaN       NaN      NaN            NaN
# 1             NaN       NaN      NaN            NaN
# 1             NaN       NaN      NaN            NaN
# 1             NaN       NaN      NaN            NaN
# 1             NaN       NaN      NaN            NaN
# 1             NaN       NaN      NaN            NaN
# 2             NaN       NaN      NaN            NaN
# 3             NaN       NaN      NaN            NaN
# 4             NaN       NaN      NaN            NaN
# 5             NaN       NaN      NaN            NaN
# 6             NaN       NaN      NaN            NaN
# 6             NaN       NaN      NaN            NaN
# 6             NaN       NaN      NaN            NaN
# 6             NaN       NaN      NaN            NaN
# 6             NaN       NaN      NaN            NaN
# 6             NaN       NaN      NaN            NaN
# 6             NaN       NaN      NaN            NaN
# 6             NaN       NaN      NaN            NaN
# 6             NaN       NaN      NaN            NaN
# 6             NaN       NaN      NaN            NaN
# 7             NaN       NaN      NaN            NaN
# 8             NaN       NaN      NaN            NaN
# 9             NaN       NaN      NaN            NaN
# 9             NaN       NaN      NaN            NaN
# 9             NaN       NaN      NaN            NaN
# ...           ...       ...      ...            ...
# 67            NaN       NaN      NaN            NaN
# 68            NaN       NaN      NaN            NaN
# 69            NaN       NaN      NaN            NaN
# 70        5.91429  0.771903  3.00675        1.38059
# 70        6.08444  0.784221  3.63674        2.19264
# 70        6.05262  0.781944    2.722        1.26768
# 70        5.64522  0.751681  4.96447        1.92502
# 70        5.60107  0.748271  3.89616        2.09951
# 70        5.83031  0.765691   2.7399        1.24774
# 70        6.27744  0.797783  3.79651        1.71376
# 70        6.23814  0.795055  2.35715        1.03357
# 70        6.29066  0.798696  2.21206        1.03417
# 70        5.99269  0.777249  3.25908        1.54385
# 71            NaN       NaN      NaN            NaN
# 72            NaN       NaN      NaN            NaN
# 73        2.69896  0.431197  1.55477     -0.0636586
# 73        2.58688  0.412777  1.57854      -0.165504
# 73        2.71304  0.433455  1.59349      -0.152936
# 73        2.66133  0.425099  1.55708      -0.107229
# 73        2.52954  0.403041  1.57682      -0.201337
# 73         2.6442  0.422294  1.57495       -0.17174
# 73        2.75757  0.440527  1.54979      -0.116781
# 73        2.65016  0.423272  1.54791      -0.144142
# 73         2.7185  0.434329  1.57618      -0.100561
# 73        2.66224   0.42511  1.56773      -0.135987
# 74            NaN       NaN      NaN            NaN
# 75            NaN       NaN      NaN            NaN
# 76            NaN       NaN      NaN            NaN
# 77            NaN       NaN      NaN            NaN
# 77            NaN       NaN      NaN            NaN
#
# [252 rows x 11 columns]

# %% [markdown]
# ### Compare layers   (in blue cases)

# %%
before_checkpoint = 'checkpoint_trained_4D_regularized_5Lremoved.pth.tar'
after_checkpoint =  'checkpoint_trained_4D_regularized_5Lremoved_finetuned.pth.tar'



try:
    file = before_checkpoint
    logger.info(file)
    checkpoint_file = "/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/"+file

    before_model = create_model(False, 'cifar10', 'resnet20_cifar', parallel=True)
    load_checkpoint(before_model, checkpoint_file);
    
    file = after_checkpoint
    logger.info(file)
    checkpoint_file = "/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/"+file

    after_model = create_model(False, 'cifar10', 'resnet20_cifar', parallel=True)
    load_checkpoint(after_model, checkpoint_file);

except Exception as e:
    print("Did you forget to download the checkpoint file?")
    raise e
# Out:
# INFO:__main__:checkpoint_trained_4D_regularized_5Lremoved.pth.tar
# INFO:root:=> creating resnet20_cifar model for CIFAR10
# INFO:root:=> loading checkpoint /Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_4D_regularized_5Lremoved.pth.tar
# INFO:root:=> Checkpoint contents:
# ╒═══════════════════╤═════════════╤════════════════╕
# │ Key               │ Type        │ Value          │
# ╞═══════════════════╪═════════════╪════════════════╡
# │ arch              │ str         │ resnet20_cifar │
# ├───────────────────┼─────────────┼────────────────┤
# │ best_top1         │ float       │ 90.62          │
# ├───────────────────┼─────────────┼────────────────┤
# │ compression_sched │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ epoch             │ int         │ 179            │
# ├───────────────────┼─────────────┼────────────────┤
# │ optimizer         │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ state_dict        │ OrderedDict │                │
# ╘═══════════════════╧═════════════╧════════════════╛
#
# INFO:root:Loaded compression schedule from checkpoint (epoch 179)
# WARNING:root:Optimizer could not be loaded from checkpoint.
# INFO:root:=> loaded checkpoint '/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_4D_regularized_5Lremoved.pth.tar' (epoch 179)
# INFO:__main__:checkpoint_trained_4D_regularized_5Lremoved_finetuned.pth.tar
# INFO:root:=> creating resnet20_cifar model for CIFAR10
# INFO:root:=> loading checkpoint /Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_4D_regularized_5Lremoved_finetuned.pth.tar
# INFO:root:=> Checkpoint contents:
# ╒═══════════════════╤═════════════╤════════════════╕
# │ Key               │ Type        │ Value          │
# ╞═══════════════════╪═════════════╪════════════════╡
# │ arch              │ str         │ resnet20_cifar │
# ├───────────────────┼─────────────┼────────────────┤
# │ best_top1         │ float       │ 94.24          │
# ├───────────────────┼─────────────┼────────────────┤
# │ compression_sched │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ epoch             │ int         │ 249            │
# ├───────────────────┼─────────────┼────────────────┤
# │ optimizer         │ dict        │                │
# ├───────────────────┼─────────────┼────────────────┤
# │ state_dict        │ OrderedDict │                │
# ╘═══════════════════╧═════════════╧════════════════╛
#
# INFO:root:Loaded compression schedule from checkpoint (epoch 249)
# WARNING:root:Optimizer could not be loaded from checkpoint.
# INFO:root:=> loaded checkpoint '/Users/charleshmartin/work/distiller/examples/ssl/checkpoints/checkpoint_trained_4D_regularized_5Lremoved_finetuned.pth.tar' (epoch 249)

# %%
import powerlaw
from sklearn.decomposition import TruncatedSVD

# %%
layers_before  = before_model.modules()
layers_after = after_model.modules()

labels = ['before', 'after']
for lb, la in zip(layers_before, layers_after):
    print(type(lb))
    if (type(lb)==torch.nn.modules.linear.Linear):
        print("==========\n",lb)
        for i,l in enumerate([lb, la]):
                         
            W = [np.array(l.weight.data.clone().cpu())][0]
            N, M = np.max(W.shape), np.min(W.shape)
      
            svd = TruncatedSVD(n_components=M-1)        
            svd.fit(W)

            sv = svd.singular_values_
            ev = sv*sv
            max_ev =  np.max(ev)

            plt.hist(ev,  bins=np.min([M,100]),  density=True, alpha=0.25, label=labels[i]);
       
            fit = powerlaw.Fit(ev, xmax=max_ev)
            randP = fit.loglikelihood_ratio('power_law', 'truncated_power_law')
            print("alpha w/xmax ", fit.alpha)
            print("truncated alpha ? ", randP)
            print("alpha log xmax ", fit.alpha*np.log10(max_ev))

          
            print("norm W ", np.linalg.norm(W))
            print("max ev ", max_ev )

        plt.legend()
        plt.title("FC {}".format(l))
        plt.show()
# Out:
# Calculating best minimal value for power law fit
# Assuming nested distributions
# Calculating best minimal value for power law fit
# Assuming nested distributions
# <class 'distiller.models.cifar10.resnet_cifar.ResNetCifar'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.container.Sequential'>
# <class 'distiller.models.cifar10.resnet_cifar.BasicBlock'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'distiller.models.cifar10.resnet_cifar.BasicBlock'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'distiller.models.cifar10.resnet_cifar.BasicBlock'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.container.Sequential'>
# <class 'distiller.models.cifar10.resnet_cifar.BasicBlock'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.container.Sequential'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'distiller.models.cifar10.resnet_cifar.BasicBlock'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'distiller.models.cifar10.resnet_cifar.BasicBlock'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.container.Sequential'>
# <class 'distiller.models.cifar10.resnet_cifar.BasicBlock'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.container.Sequential'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'distiller.models.cifar10.resnet_cifar.BasicBlock'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'distiller.models.cifar10.resnet_cifar.BasicBlock'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.conv.Conv2d'>
# <class 'torch.nn.modules.batchnorm.BatchNorm2d'>
# <class 'torch.nn.modules.activation.ReLU'>
# <class 'torch.nn.modules.pooling.AvgPool2d'>
# <class 'torch.nn.modules.linear.Linear'>
# ==========
#  Linear(in_features=64, out_features=10, bias=True)
# alpha w/xmax  3.694970706027387
# truncated alpha ?  (-0.247709126752516, 0.4815202496966179)
# alpha log xmax  6.099469961174222
# norm W  14.746689
# max ev  44.745483
# alpha w/xmax  4.125924805080487
# truncated alpha ?  (-0.1318568227571757, 0.6075802329913222)
# alpha log xmax  6.638420072954311
# norm W  14.1501
# max ev  40.639957

# %% [markdown]
# ## Comparing the ResNet 4D_regularized before and after finetuning reaults

# %%
watcher = ww.WeightWatcher(model=before_model, logger=logger)
before_results = watcher.analyze(compute_alphas=True)
before_summary = watcher.get_summary()
# Out:
# INFO:__main__:
# WeightWatcher v0.1.2 by Calculation Consulting
# Analyze weight matrices of Deep Neural Networks
# https://calculationconsulting.com/
# python      version 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.15.3
# tensforflow version 1.10.1
# keras       version 2.2.2
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 0.7295551300048828, max: 7.41560173034668, avg: 4.315795421600342
# INFO:__main__:Norm compound: min: 0.8330910801887512, max: 6.924064636230469, avg: 4.315794944763184
# INFO:__main__:LogNorm: min: -0.13694187998771667, max: 0.8701463937759399, avg: 0.5175516605377197
# INFO:__main__:LogNorm compound: min: -0.08011464774608612, max: 0.8399592638015747, avg: 0.517551600933075
# INFO:__main__:Alpha: min: 1.490533392059119, max: 10.44447500619053, avg: 3.196053477405699
# INFO:__main__:Alpha compound: min: 1.5256002825714163, max: 4.1041530584371255, avg: 3.196053477405699
# INFO:__main__:Alpha Weighted: min: -4.778228304138091, max: 4.84831647823597, avg: 0.3071941264704492
# INFO:__main__:Alpha Weighted compound: min: -2.236248250745935, max: 1.842976302987391, avg: 0.30719412647044925

# %%
watcher = ww.WeightWatcher(model=after_model, logger=logger)
after_results = watcher.analyze(compute_alphas=True)
after_summary = watcher.get_summary()
# Out:
# INFO:__main__:
# WeightWatcher v0.1.2 by Calculation Consulting
# Analyze weight matrices of Deep Neural Networks
# https://calculationconsulting.com/
# python      version 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# numpy       version 1.15.3
# tensforflow version 1.10.1
# keras       version 2.2.2
# INFO:__main__:Analyzing model
# INFO:__main__:### Printing results ###
# INFO:__main__:Norm: min: 2.5295395851135254, max: 7.4775214195251465, avg: 5.17536735534668
# INFO:__main__:Norm compound: min: 2.6622424125671387, max: 6.906456470489502, avg: 5.175367832183838
# INFO:__main__:LogNorm: min: 0.4030414819717407, max: 0.8737576603889465, avg: 0.6895095109939575
# INFO:__main__:LogNorm compound: min: 0.42511019110679626, max: 0.8387784361839294, avg: 0.6895094513893127
# INFO:__main__:Alpha: min: 1.547911240590813, max: 6.215031447044829, avg: 2.9283534919514183
# INFO:__main__:Alpha compound: min: 1.5677253169822416, max: 3.4840509191567137, avg: 2.9283534919514183
# INFO:__main__:Alpha Weighted: min: -0.20133656185538537, max: 2.4306535014449824, avg: 1.0113115613133257
# INFO:__main__:Alpha Weighted compound: min: -0.13598742569002653, max: 1.7519840569712983, avg: 1.0113115613133257

# %%
def get_all_metrics(results, metric='norm'):
    all_metrics = []
    for k,v in results.items():
        if 'layer_type' in v:
            for k in v.keys():
                if type(v[k]) is dict:
                    if metric in v[k]:
                        all_metrics.append(v[k][metric])
    return all_metrics

# %%
before_metrics = get_all_metrics(before_results)
after_metrics =  get_all_metrics(after_results)

plt.scatter(np.arange(len(before_metrics)), before_metrics, color='green')
plt.scatter(np.arange(len(after_metrics)), after_metrics, color='red')
plt.title(" ResNet 4D_regularized \n Before vs After Norms")
# Out:
# Text(0.5,1,' ResNet 4D_regularized \n Before vs After Norms')

# %%
before_metrics = get_all_metrics(before_results, metric='alpha')
after_metrics =  get_all_metrics(after_results, metric='alpha')

plt.scatter(np.arange(len(before_metrics)), before_metrics, color='green')
plt.scatter(np.arange(len(after_metrics)), after_metrics, color='red')
plt.title(" ResNet 4D_regularized \n Before vs After Alphas")
# Out:
# Text(0.5,1,' ResNet 4D_regularized \n Before vs After Alphas')

# %%
before_metrics = get_all_metrics(before_results, metric='lambda_max')
after_metrics =  get_all_metrics(after_results, metric='lambda_max')

plt.scatter(np.arange(len(before_metrics)), before_metrics, color='green')
plt.scatter(np.arange(len(after_metrics)), after_metrics, color='red')
plt.title(" ResNet 4D_regularized \n Before vs After Spectral Norm (Max Eigenvalue)")
# Out:
# Text(0.5,1,' ResNet 4D_regularized \n Before vs After Spectral Norm (Max Eigenvalue)')

# %%
before_metrics = get_all_metrics(before_results, metric='alpha_weighted')
after_metrics =  get_all_metrics(after_results, metric='alpha_weighted')

plt.scatter(np.arange(len(before_metrics)), before_metrics, color='green')
plt.scatter(np.arange(len(after_metrics)), after_metrics, color='red')
plt.title(" ResNet 4D_regularized \n Before vs After Weighted Alpha ")
# Out:
# Text(0.5,1,' ResNet 4D_regularized \n Before vs After Weighted Alpha ')
